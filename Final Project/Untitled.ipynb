# %%
youtube <- read.csv('DEvideos.csv')
guncrimes <- read.csv('stage3.csv')

# %%
youtube
# Out:
#       video_id    trending_date
# 1     LgVi6y5QIjM 17.14.11
# 2     Bayt7uQith4 17.14.11
# 3     1ZAPwfrtAFY 17.14.11
# 4     AHtypnRk7JE 17.14.11
# 5     ZJ9We4bjcg0 17.14.11
# 6     xapGFgWqtg4 17.14.11
# 7     EIM7RMe39JY 17.14.11
# 8     PaWTaj6Iie0 17.14.11
# 9     GHct2dGNLks 17.14.11
# 10    aZYSFByDGkg 17.14.11
# 11    2hu_evXPpMM 17.14.11
# 12    2kyS6SvSYSE 17.14.11
# 13    2Zp-Qm3wJkA 17.14.11
# 14    mmMPprcmJeA 17.14.11
# 15    3U51cVIqulM 17.14.11
# 16    OKYUtHvgMhc 17.14.11
# 17    spwqQDCW4TI 17.14.11
# 18    -MAgDuA3H9A 17.14.11
# 19    riV8xuBqUQ0 17.14.11
# 20    nNtrjfX2aGw 17.14.11
# 21    k_IrAnVSjYE 17.14.11
# 22    KLxP8VxZjlk 17.14.11
# 23    cJx5blgWjDw 17.14.11
# 24    FWoXtrLTUMs 17.14.11
# 25    PK8lHszeXNk 17.14.11
# 26    BEVPWKNRrQQ 17.14.11
# 27    lqJbw2pWZLk 17.14.11
# 28    hg0OwRhQpGE 17.14.11
# 29    XVpDYrjZnuI 17.14.11
# 30    A5LFlKGs5wA 17.14.11
# ...   ...         ...
# 40811 mpnshdmtE2Y 18.14.06
# 40812 OqjwJ3EY1V4 18.14.06
# ...

# %%
guncrimes
# Out:
#        incident_id date       state                city_or_county
# 1      461105      2013-01-01 Pennsylvania         Mckeesport
# 2      460726      2013-01-01 California           Hawthorne
# 3      478855      2013-01-01 Ohio                 Lorain
# 4      478925      2013-01-05 Colorado             Aurora
# 5      478959      2013-01-07 North Carolina       Greensboro
# 6      478948      2013-01-07 Oklahoma             Tulsa
# 7      479363      2013-01-19 New Mexico           Albuquerque
# 8      479374      2013-01-21 Louisiana            New Orleans
# 9      479389      2013-01-21 California           Brentwood
# 10     492151      2013-01-23 Maryland             Baltimore
# 11     491674      2013-01-23 Tennessee            Chattanooga
# 12     479413      2013-01-25 Missouri             Saint Louis
# 13     479561      2013-01-26 Louisiana            Charenton
# 14     479554      2013-01-26 District of Columbia Washington
# ...

# %%
#Is there a correlation between the amount of likes/ dislikes and the possibility to comment on a video?
#Do the amount of comments vary between different languages in relation to views? 
#Does the amount of comments have an influence on the popularity of videos over time?
#Does the amount of views per video increase/ decrease in relation to the language over time?





#https://www.kaggle.com/datasnaek/youtube-new/tasks
